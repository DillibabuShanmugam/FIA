# %%
data = {
    "hashid": {
        "4": "msp430Inst_0",
        "5": "msp430Inst_1",
        "6": "msp430Inst_2",
        "7": "msp430Inst_3",
        "8": "msp430Inst_4",
        "9": "msp430Inst_5",
        "16": "msp430Inst_0.openmsp430_0",
        "25": "msp430Inst_1.openmsp430_0",
        "34": "msp430Inst_2.openmsp430_0",
        "43": "msp430Inst_3.openmsp430_0",
        "52": "msp430Inst_4.openmsp430_0",
        "61": "msp430Inst_5.openmsp430_0",
        "153": "openmsp430_0.watchdog_0",
        "154": "openmsp430_0.sfr_0",
        "155": "openmsp430_0.multiplier_0",
        "156": "openmsp430_0.mem_backbone_0",
        "157": "openmsp430_0.frontend_0",
        "158": "openmsp430_0.execution_unit_0",
        "159": "openmsp430_0.dbg_0",
        "160": "openmsp430_0.clock_module_0",
        "372": "openmsp430_1.watchdog_0",
        "373": "openmsp430_1.sfr_0",
        "374": "openmsp430_1.multiplier_0",
        "375": "openmsp430_1.mem_backbone_0",
        "376": "openmsp430_1.frontend_0",
        "377": "openmsp430_1.execution_unit_0",
        "378": "openmsp430_1.dbg_0",
        "379": "openmsp430_1.clock_module_0",
        "591": "openmsp430_2.watchdog_0",
        "592": "openmsp430_2.sfr_0",
        "593": "openmsp430_2.multiplier_0",
        "594": "openmsp430_2.mem_backbone_0",
        "595": "openmsp430_2.frontend_0",
        "596": "openmsp430_2.execution_unit_0",
        "597": "openmsp430_2.dbg_0",
        "598": "openmsp430_2.clock_module_0",
        "810": "openmsp430_3.watchdog_0",
        "811": "openmsp430_3.sfr_0",
        "812": "openmsp430_3.multiplier_0",
        "813": "openmsp430_3.mem_backbone_0",
        "814": "openmsp430_3.frontend_0",
        "815": "openmsp430_3.execution_unit_0",
        "816": "openmsp430_3.dbg_0",
        "817": "openmsp430_3.clock_module_0",
        "1029": "openmsp430_4.watchdog_0",
        "1030": "openmsp430_4.sfr_0",
        "1031": "openmsp430_4.multiplier_0",
        "1032": "openmsp430_4.mem_backbone_0",
        "1033": "openmsp430_4.frontend_0",
        "1034": "openmsp430_4.execution_unit_0",
        "1035": "openmsp430_4.dbg_0",
        "1036": "openmsp430_4.clock_module_0",
        "1248": "openmsp430_5.watchdog_0",
        "1249": "openmsp430_5.sfr_0",
        "1250": "openmsp430_5.multiplier_0",
        "1251": "openmsp430_5.mem_backbone_0",
        "1252": "openmsp430_5.frontend_0",
        "1253": "openmsp430_5.execution_unit_0",
        "1254": "openmsp430_5.dbg_0",
        "1255": "openmsp430_5.clock_module_0",
        "12352": "openmsp430_0.archi",
        "12353": "openmsp430_1.archi",
        "12354": "openmsp430_2.archi",
        "12355": "openmsp430_3.archi",
        "12356": "openmsp430_4.archi",
        "12357": "openmsp430_5.archi",
        "1899": "openmsp430_0.watchdog_0.wdtctl",
        "1902": "openmsp430_0.sfr_0.wdtie_reg",
        "1903": "openmsp430_0.sfr_0.nmiifg_reg",
        "1904": "openmsp430_0.sfr_0.nmie_reg",
        "1905": "openmsp430_0.sfr_0.nmi_dly_reg",
        "1906": "openmsp430_0.multiplier_0.sumext_s",
        "1908": "openmsp430_0.multiplier_0.reslo",
        "1909": "openmsp430_0.multiplier_0.reshi",
        "1910": "openmsp430_0.multiplier_0.op2",
        "1911": "openmsp430_0.multiplier_0.op1",
        "1921": "openmsp430_0.frontend_0.pc",
        "1944": "openmsp430_0.execution_unit_0.register_file_0",
        "1953": "openmsp430_0.dbg_0.mem_data",
        "1954": "openmsp430_0.dbg_0.mem_ctl",
        "1955": "openmsp430_0.dbg_0.mem_cnt",
        "1957": "openmsp430_0.dbg_0.mem_addr",
        "1963": "openmsp430_0.dbg_0.cpu_stat",
        "1964": "openmsp430_0.dbg_0.cpu_ctl",
        "1972": "openmsp430_0.clock_module_0.bcsctl2",
        "1973": "openmsp430_0.clock_module_0.bcsctl1",
        "2865": "openmsp430_1.watchdog_0.wdtctl",
        "2868": "openmsp430_1.sfr_0.wdtie_reg",
        "2869": "openmsp430_1.sfr_0.nmiifg_reg",
        "2870": "openmsp430_1.sfr_0.nmie_reg",
        "2871": "openmsp430_1.sfr_0.nmi_dly_reg",
        "2872": "openmsp430_1.multiplier_0.sumext_s",
        "2874": "openmsp430_1.multiplier_0.reslo",
        "2875": "openmsp430_1.multiplier_0.reshi",
        "2876": "openmsp430_1.multiplier_0.op2",
        "2877": "openmsp430_1.multiplier_0.op1",
        "2887": "openmsp430_1.frontend_0.pc",
        "2910": "openmsp430_1.execution_unit_0.register_file_0",
        "2919": "openmsp430_1.dbg_0.mem_data",
        "2920": "openmsp430_1.dbg_0.mem_ctl",
        "2921": "openmsp430_1.dbg_0.mem_cnt",
        "2923": "openmsp430_1.dbg_0.mem_addr",
        "2929": "openmsp430_1.dbg_0.cpu_stat",
        "2930": "openmsp430_1.dbg_0.cpu_ctl",
        "2938": "openmsp430_1.clock_module_0.bcsctl2",
        "2939": "openmsp430_1.clock_module_0.bcsctl1",
        "3831": "openmsp430_2.watchdog_0.wdtctl",
        "3834": "openmsp430_2.sfr_0.wdtie_reg",
        "3835": "openmsp430_2.sfr_0.nmiifg_reg",
        "3836": "openmsp430_2.sfr_0.nmie_reg",
        "3837": "openmsp430_2.sfr_0.nmi_dly_reg",
        "3838": "openmsp430_2.multiplier_0.sumext_s",
        "3840": "openmsp430_2.multiplier_0.reslo",
        "3841": "openmsp430_2.multiplier_0.reshi",
        "3842": "openmsp430_2.multiplier_0.op2",
        "3843": "openmsp430_2.multiplier_0.op1",
        "3853": "openmsp430_2.frontend_0.pc",
        "3876": "openmsp430_2.execution_unit_0.register_file_0",
        "3885": "openmsp430_2.dbg_0.mem_data",
        "3886": "openmsp430_2.dbg_0.mem_ctl",
        "3887": "openmsp430_2.dbg_0.mem_cnt",
        "3889": "openmsp430_2.dbg_0.mem_addr",
        "3895": "openmsp430_2.dbg_0.cpu_stat",
        "3896": "openmsp430_2.dbg_0.cpu_ctl",
        "3904": "openmsp430_2.clock_module_0.bcsctl2",
        "3905": "openmsp430_2.clock_module_0.bcsctl1",
        "4797": "openmsp430_3.watchdog_0.wdtctl",
        "4800": "openmsp430_3.sfr_0.wdtie_reg",
        "4801": "openmsp430_3.sfr_0.nmiifg_reg",
        "4802": "openmsp430_3.sfr_0.nmie_reg",
        "4803": "openmsp430_3.sfr_0.nmi_dly_reg",
        "4804": "openmsp430_3.multiplier_0.sumext_s",
        "4806": "openmsp430_3.multiplier_0.reslo",
        "4807": "openmsp430_3.multiplier_0.reshi",
        "4808": "openmsp430_3.multiplier_0.op2",
        "4809": "openmsp430_3.multiplier_0.op1",
        "4819": "openmsp430_3.frontend_0.pc",
        "4842": "openmsp430_3.execution_unit_0.register_file_0",
        "4851": "openmsp430_3.dbg_0.mem_data",
        "4852": "openmsp430_3.dbg_0.mem_ctl",
        "4853": "openmsp430_3.dbg_0.mem_cnt",
        "4855": "openmsp430_3.dbg_0.mem_addr",
        "4861": "openmsp430_3.dbg_0.cpu_stat",
        "4862": "openmsp430_3.dbg_0.cpu_ctl",
        "4870": "openmsp430_3.clock_module_0.bcsctl2",
        "4871": "openmsp430_3.clock_module_0.bcsctl1",
        "5763": "openmsp430_4.watchdog_0.wdtctl",
        "5766": "openmsp430_4.sfr_0.wdtie_reg",
        "5767": "openmsp430_4.sfr_0.nmiifg_reg",
        "5768": "openmsp430_4.sfr_0.nmie_reg",
        "5769": "openmsp430_4.sfr_0.nmi_dly_reg",
        "5770": "openmsp430_4.multiplier_0.sumext_s",
        "5772": "openmsp430_4.multiplier_0.reslo",
        "5773": "openmsp430_4.multiplier_0.reshi",
        "5774": "openmsp430_4.multiplier_0.op2",
        "5775": "openmsp430_4.multiplier_0.op1",
        "5785": "openmsp430_4.frontend_0.pc",
        "5808": "openmsp430_4.execution_unit_0.register_file_0",
        "5817": "openmsp430_4.dbg_0.mem_data",
        "5818": "openmsp430_4.dbg_0.mem_ctl",
        "5819": "openmsp430_4.dbg_0.mem_cnt",
        "5821": "openmsp430_4.dbg_0.mem_addr",
        "5827": "openmsp430_4.dbg_0.cpu_stat",
        "5828": "openmsp430_4.dbg_0.cpu_ctl",
        "5836": "openmsp430_4.clock_module_0.bcsctl2",
        "5837": "openmsp430_4.clock_module_0.bcsctl1",
        "6729": "openmsp430_5.watchdog_0.wdtctl",
        "6732": "openmsp430_5.sfr_0.wdtie_reg",
        "6733.": "openmsp430_5.sfr_0.nmiifg_reg",
        "6734": "openmsp430_5.sfr_0.nmie_reg",
        "6735": "openmsp430_5.sfr_0.nmi_dly_reg",
        "6736": "openmsp430_5.multiplier_0.sumext_s",
        "6738": "openmsp430_5.multiplier_0.reslo",
        "6739": "openmsp430_5.multiplier_0.reshi",
        "6740": "openmsp430_5.multiplier_0.op2",
        "6741": "openmsp430_5.multiplier_0.op1",
        "6751": "openmsp430_5.frontend_0.pc",
        "6774": "openmsp430_5.execution_unit_0.register_file_0",
        "6783": "openmsp430_5.dbg_0.mem_data",
        "6784": "openmsp430_5.dbg_0.mem_ctl",
        "6785": "openmsp430_5.dbg_0.mem_cnt",
        "6787": "openmsp430_5.dbg_0.mem_addr",
        "6793": "openmsp430_5.dbg_0.cpu_stat",
        "6794": "openmsp430_5.dbg_0.cpu_ctl",
        "6802": "openmsp430_5.clock_module_0.bcsctl2",
        "6803": "openmsp430_5.clock_module_0.bcsctl1"
    }
}

# Extract and print lines containing "openmsp430_0"
C_0 = {key: value for key, value in data["hashid"].items() if "openmsp430_0" in value}
C_1 = {key: value for key, value in data["hashid"].items() if "openmsp430_1" in value}
C_2 = {key: value for key, value in data["hashid"].items() if "openmsp430_2" in value}
C_3 = {key: value for key, value in data["hashid"].items() if "openmsp430_3" in value}
C_4 = {key: value for key, value in data["hashid"].items() if "openmsp430_4" in value}
C_5 = {key: value for key, value in data["hashid"].items() if "openmsp430_5" in value}
print(C_0,C_1,C_3,C_4,C_5)
#print(len(result))
# Out:
# {'16': 'msp430Inst_0.openmsp430_0', '25': 'msp430Inst_1.openmsp430_0', '34': 'msp430Inst_2.openmsp430_0', '43': 'msp430Inst_3.openmsp430_0', '52': 'msp430Inst_4.openmsp430_0', '61': 'msp430Inst_5.openmsp430_0', '153': 'openmsp430_0.watchdog_0', '154': 'openmsp430_0.sfr_0', '155': 'openmsp430_0.multiplier_0', '156': 'openmsp430_0.mem_backbone_0', '157': 'openmsp430_0.frontend_0', '158': 'openmsp430_0.execution_unit_0', '159': 'openmsp430_0.dbg_0', '160': 'openmsp430_0.clock_module_0', '12352': 'openmsp430_0.archi', '1899': 'openmsp430_0.watchdog_0.wdtctl', '1902': 'openmsp430_0.sfr_0.wdtie_reg', '1903': 'openmsp430_0.sfr_0.nmiifg_reg', '1904': 'openmsp430_0.sfr_0.nmie_reg', '1905': 'openmsp430_0.sfr_0.nmi_dly_reg', '1906': 'openmsp430_0.multiplier_0.sumext_s', '1908': 'openmsp430_0.multiplier_0.reslo', '1909': 'openmsp430_0.multiplier_0.reshi', '1910': 'openmsp430_0.multiplier_0.op2', '1911': 'openmsp430_0.multiplier_0.op1', '1921': 'openmsp430_0.frontend_0.pc', '1944': 'openmsp430_0.
# ...

# %%
# Out:
# openmsp430_0: ['16', '25', '34', '43', '52', '61', '153', '154', '155', '156', '157', '158', '159', '160', '12352', '1899', '1902', '1903', '1904', '1905', '1906', '1908', '1909', '1910', '1911', '1921', '1944', '1953', '1954', '1955', '1957', '1963', '1964', '1972', '1973']
# openmsp430_1: ['372', '373', '374', '375', '376', '377', '378', '379', '12353', '2865', '2868', '2869', '2870', '2871', '2872', '2874', '2875', '2876', '2877', '2887', '2910', '2919', '2920', '2921', '2923', '2929', '2930', '2938', '2939']
# openmsp430_2: ['591', '592', '593', '594', '595', '596', '597', '598', '12354', '3831', '3834', '3835', '3836', '3837', '3838', '3840', '3841', '3842', '3843', '3853', '3876', '3885', '3886', '3887', '3889', '3895', '3896', '3904', '3905']
# ...

# %%
# Print hashid values
print("Hashid values:")
ids_to_extract_1 =[]

for key in C_1.keys():
    ids_to_extract_1.append(key)
print(ids_to_extract_1)
# Out:
# Hashid values:
# ['372', '373', '374', '375', '376', '377', '378', '379', '12353', '2865', '2868', '2869', '2870', '2871', '2872', '2874', '2875', '2876', '2877', '2887', '2910', '2919', '2920', '2921', '2923', '2929', '2930', '2938', '2939']

# %%
import os
import json
import csv

# Define the IDs you want to extract
ids_to_extract = [
    4, 16, 153, 154, 155, 156, 157, 158, 159, 160,
    12352, 1899, 1902, 1903, 1904, 1905, 1906, 1908, 1909, 1910, 1911,
    1921, 1944, 1953, 1954, 1955, 1957, 1963, 1964, 1972, 1973
]

# Function to extract hashes for a given cycle
def extract_hashes_for_cycle(data, cycle):
    cycle_data = next((item for item in data['digest'] if item['cycle'] == str(cycle)), None)
    if cycle_data:
        return [cycle_data['hash'].get(str(id_), '') for id_ in ids_to_extract]
    return [''] * len(ids_to_extract)

# Base directory
base_dir = 'glitchsweep_fsm_red'

# Traverse the base directory and subdirectories
for root, dirs, files in os.walk(base_dir):
    if 'hashdata.json' in files:
        file_path = os.path.join(root, 'hashdata.json')
        with open(file_path, 'r') as f:
            data = json.load(f)
        
        # Initialize the results list for this directory
        results = []

        # Process cycles from 7 to 34
        for cycle in range(7, 35):
            row = extract_hashes_for_cycle(data, cycle)
            results.append(row)
        
        # Extract the directory name for the CSV file
        dir_name = os.path.basename(root)
        csv_file_name = f'extracted_hashes_{dir_name}.csv'
        csv_file_path = os.path.join(base_dir, csv_file_name)
        
        # Create the CSV file with the directory name
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(ids_to_extract)  # Write header
            writer.writerows(results)  # Write data rows

        print(f"CSV file created: {csv_file_path}")
# Out:
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-13cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-34cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-16cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-26cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-10cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-9cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-23cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-32cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-22cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-11cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-15cc.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-correct.csv
# ...

# %%
import os
import json
import csv

# Define the ID sets
openmsp430_0 = [
    '4', '16', '153', '154', '155', '156', '157', '158', '159', '160', '12352', '1899', '1902', '1903', 
    '1904', '1905', '1906', '1908', '1909', '1910', '1911', '1921', '1944', '1953', '1954', '1955', '1957', 
    '1963', '1964', '1972', '1973'
]
openmsp430_1 = [
    '5', '25', '372', '373', '374', '375', '376', '377', '378', '379', '12353', '2865', '2868', '2869', 
    '2870', '2871', '2872', '2874', '2875', '2876', '2877', '2887', '2910', '2919', '2920', '2921', '2923', 
    '2929', '2930', '2938', '2939'
]
openmsp430_2 = [
    '6', '34', '591', '592', '593', '594', '595', '596', '597', '598', '12354', '3831', '3834', '3835', 
    '3836', '3837', '3838', '3840', '3841', '3842', '3843', '3853', '3876', '3885', '3886', '3887', '3889', 
    '3895', '3896', '3904', '3905'
]
openmsp430_3 = [
    '7', '43', '810', '811', '812', '813', '814', '815', '816', '817', '12355', '4797', '4800', '4801', 
    '4802', '4803', '4804', '4806', '4807', '4808', '4809', '4819', '4842', '4851', '4852', '4853', '4855', 
    '4861', '4862', '4870', '4871'
]
openmsp430_4 = [
    '8', '52', '1029', '1030', '1031', '1032', '1033', '1034', '1035', '1036', '12356', '5763', '5766', 
    '5767', '5768', '5769', '5770', '5772', '5773', '5774', '5775', '5785', '5808', '5817', '5818', '5819', 
    '5821', '5827', '5828', '5836', '5837'
]
openmsp430_5 = [
    '9', '61', '1248', '1249', '1250', '1251', '1252', '1253', '1254', '1255', '12357', '6729', '6732', 
    '6733.', '6734', '6735', '6736', '6738', '6739', '6740', '6741', '6751', '6774', '6783', '6784', '6785', 
    '6787', '6793', '6794', '6802', '6803'
]

# Folders to exclude
exclude_folders = ['tb-13cc', 'tb-20cc', 'tb-27cc', 'tb-30cc', 'tb-34cc']

# Function to extract hashes for a given cycle using a specific set of IDs
def extract_hashes_for_cycle(data, cycle, ids):
    cycle_data = next((item for item in data['digest'] if item['cycle'] == str(cycle)), None)
    if cycle_data:
        return [cycle_data['hash'].get(id_, '') for id_ in ids]
    return [''] * len(ids)

# Base directory
base_dir = 'glitchsweep_fsm_red'

# ID sets and corresponding filenames
id_sets = {
    'openmsp430_0': openmsp430_0,
    'openmsp430_1': openmsp430_1,
    'openmsp430_2': openmsp430_2,
    'openmsp430_3': openmsp430_3,
    'openmsp430_4': openmsp430_4,
    'openmsp430_5': openmsp430_5
}

# Traverse the base directory and subdirectories
for root, dirs, files in os.walk(base_dir):
    folder_name = os.path.basename(root)
    if folder_name in exclude_folders:
        continue
    
    if 'hashdata.json' in files:
        file_path = os.path.join(root, 'hashdata.json')
        with open(file_path, 'r') as f:
            data = json.load(f)
        
        # Process each set of IDs
        for set_name, ids in id_sets.items():
            # Initialize the results list for this ID set
            results = []

            # Process cycles from 7 to 34
            for cycle in range(7, 35):
                row = extract_hashes_for_cycle(data, cycle, ids)
                results.append(row)
            
            # Create the CSV file name
            csv_file_name = f'extracted_hashes_{folder_name}_{set_name}.csv'
            csv_file_path = os.path.join(base_dir, csv_file_name)
            
            # Create the CSV file with the set name
            with open(csv_file_path, 'w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(ids)  # Write header
                writer.writerows(results)  # Write data rows

            print(f"CSV file created: {csv_file_path}")
# Out:
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_0.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_1.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_2.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_3.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_4.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-25cc_openmsp430_5.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_0.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_1.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_2.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_3.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_4.csv
# CSV file created: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_5.csv
# ...

# %%
import os
import json
import csv

# Define the ID sets
openmsp430_0 = [
    '4', '16', '153', '154', '155', '156', '157', '158', '159', '160', '12352', '1899', '1902', '1903', 
    '1904', '1905', '1906', '1908', '1909', '1910', '1911', '1921', '1944', '1953', '1954', '1955', '1957', 
    '1963', '1964', '1972', '1973'
]
openmsp430_1 = [
    '5', '25', '372', '373', '374', '375', '376', '377', '378', '379', '12353', '2865', '2868', '2869', 
    '2870', '2871', '2872', '2874', '2875', '2876', '2877', '2887', '2910', '2919', '2920', '2921', '2923', 
    '2929', '2930', '2938', '2939'
]
openmsp430_2 = [
    '6', '34', '591', '592', '593', '594', '595', '596', '597', '598', '12354', '3831', '3834', '3835', 
    '3836', '3837', '3838', '3840', '3841', '3842', '3843', '3853', '3876', '3885', '3886', '3887', '3889', 
    '3895', '3896', '3904', '3905'
]
openmsp430_3 = [
    '7', '43', '810', '811', '812', '813', '814', '815', '816', '817', '12355', '4797', '4800', '4801', 
    '4802', '4803', '4804', '4806', '4807', '4808', '4809', '4819', '4842', '4851', '4852', '4853', '4855', 
    '4861', '4862', '4870', '4871'
]
openmsp430_4 = [
    '8', '52', '1029', '1030', '1031', '1032', '1033', '1034', '1035', '1036', '12356', '5763', '5766', 
    '5767', '5768', '5769', '5770', '5772', '5773', '5774', '5775', '5785', '5808', '5817', '5818', '5819', 
    '5821', '5827', '5828', '5836', '5837'
]
openmsp430_5 = [
    '9', '61', '1248', '1249', '1250', '1251', '1252', '1253', '1254', '1255', '12357', '6729', '6732', 
    '6733.', '6734', '6735', '6736', '6738', '6739', '6740', '6741', '6751', '6774', '6783', '6784', '6785', 
    '6787', '6793', '6794', '6802', '6803'
]

# Folders to process
folders_to_process = ['tb-13cc', 'tb-20cc', 'tb-27cc', 'tb-30cc', 'tb-34cc']

# Function to extract hashes for a given cycle using a specific set of IDs
def extract_hashes_for_cycle(data, cycle, ids):
    cycle_data = next((item for item in data['digest'] if item['cycle'] == str(cycle)), None)
    if cycle_data:
        return [cycle_data['hash'].get(id_, '') for id_ in ids]
    return [''] * len(ids)

# Base directory
base_dir = 'glitchsweep_fsm_red'

# ID sets and corresponding filenames
id_sets = {
    'openmsp430_0': openmsp430_0,
    'openmsp430_1': openmsp430_1,
    'openmsp430_2': openmsp430_2,
    'openmsp430_3': openmsp430_3,
    'openmsp430_4': openmsp430_4,
    'openmsp430_5': openmsp430_5
}

# Traverse the base directory and subdirectories
for root, dirs, files in os.walk(base_dir):
    folder_name = os.path.basename(root)
    if folder_name not in folders_to_process:
        continue
    
    if 'hashdata.json' in files:
        file_path = os.path.join(root, 'hashdata.json')
        with open(file_path, 'r') as f:
            data = json.load(f)
        
        # Process each set of IDs
        for set_name, ids in id_sets.items():
            # Initialize the results list for this ID set
            results = []

            # Process cycles from 7 to 34
            for cycle in range(7, 35):
                row = extract_hashes_for_cycle(data, cycle, ids)
                results.append(row)
            
            # Create the CSV file name
            csv_file_name = f'fault_extracted_hashes_{folder_name}_{set_name}.csv'
            csv_file_path = os.path.join(base_dir, csv_file_name)
            
            # Create the CSV file with the set name
            with open(csv_file_path, 'w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(ids)  # Write header
                writer.writerows(results)  # Write data rows

            print(f"CSV file created: {csv_file_path}")
# Out:
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_0.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_1.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_2.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_3.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_4.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-13cc_openmsp430_5.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-34cc_openmsp430_0.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-34cc_openmsp430_1.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-34cc_openmsp430_2.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-34cc_openmsp430_3.csv
# CSV file created: glitchsweep_fsm_red/fault_extracted_hashes_tb-34cc_openmsp430_4.csv
# ...

# %%
print(len(X_train))
# Out:
# 3864

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest, VotingClassifier
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.model_selection import GridSearchCV, cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns

# Define the base directory
base_dir = 'glitchsweep_fsm_red'

# ID sets (representing different hash configurations)
id_sets = ['openmsp430_0', 'openmsp430_1', 'openmsp430_2', 'openmsp430_3', 'openmsp430_4', 'openmsp430_5']

# Folders for training and validation (these are part of file names, not actual directories)
train_folder_names = [
    'tb-7cc', 'tb-8cc', 'tb-9cc', 'tb-10cc', 'tb-11cc', 'tb-12cc',
    'tb-14cc', 'tb-15cc', 'tb-16cc', 'tb-17cc', 'tb-18cc', 'tb-19cc',
    'tb-21cc', 'tb-22cc', 'tb-23cc', 'tb-24cc', 'tb-25cc', 'tb-26cc',
    'tb-28cc', 'tb-29cc', 'tb-31cc', 'tb-32cc', 'tb-33cc'
]
validation_folder_name = 'tb-13cc'  # This is part of the file name, not an actual folder

# Function to read and preprocess CSV files into 2D arrays
def read_and_preprocess_csv(file_path):
    print(f"Loading data from: {file_path}")
    df = pd.read_csv(file_path, header=None, skiprows=1)  # Skip header
    if df.empty:
        raise ValueError(f"No data found in {file_path}.")
    
    # Convert hashed values to numeric using Label Encoding
    def convert_hashes_to_numeric(df):
        label_encoders = []
        for column in df.columns:
            le = LabelEncoder()
            df[column] = le.fit_transform(df[column].astype(str))
            label_encoders.append(le)
        return df, label_encoders

    df_numeric, label_encoders = convert_hashes_to_numeric(df)
    return df_numeric.values  # Return as a NumPy array

# Step 1: Create the 3D training dataset
train_data_3d = []

for set_name in id_sets:
    for train_folder_name in train_folder_names:
        train_file = f'extracted_hashes_{train_folder_name}_{set_name}.csv'
        train_file_path = os.path.join(base_dir, train_file)

        if os.path.exists(train_file_path):
            try:
                # Read and preprocess the CSV file into a 2D array (28, 31)
                data_2d = read_and_preprocess_csv(train_file_path)
                if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                    train_data_3d.append(data_2d)
                else:
                    print(f"Unexpected data shape {data_2d.shape} in {train_file_path}. Skipping this file.")
            except Exception as e:
                print(f"Error reading or processing {train_file} in {train_folder_name}: {e}")
        else:
            print(f"Missing training file: {train_file} in {train_folder_name}")

# Convert list to a 3D NumPy array
train_data_3d = np.array(train_data_3d)  # Shape will be (138, 28, 31)

# Step 2: Train models on the 3D training dataset

# Reshape train_data_3d to (138, 28*31) for SVM
X_train_svm = train_data_3d.reshape(138, -1)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_svm)

# Tune One-Class SVM with GridSearchCV
param_grid = {'nu': [0.01, 0.05, 0.1], 'gamma': ['scale', 'auto']}
one_class_svm = GridSearchCV(OneClassSVM(kernel='rbf'), param_grid, cv=5)
one_class_svm.fit(X_train_scaled)

# Train Autoencoder
input_layer = Input(shape=(X_train_scaled.shape[1],))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(X_train_scaled.shape[1], activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
autoencoder.fit(X_train_scaled, X_train_scaled, epochs=100, batch_size=16, validation_split=0.1, verbose=0)

# Step 3: Create the 3D validation dataset and validate models
validation_data_3d = []

for set_name in id_sets:
    validate_file = f'fault_extracted_hashes_{validation_folder_name}_{set_name}.csv'
    validate_file_path = os.path.join(base_dir, validate_file)

    if os.path.exists(validate_file_path):
        try:
            # Read and preprocess the CSV file into a 2D array (28, 31)
            data_2d = read_and_preprocess_csv(validate_file_path)
            if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                validation_data_3d.append(data_2d)
            else:
                print(f"Unexpected data shape {data_2d.shape} in {validate_file_path}. Skipping this file.")
        except Exception as e:
            print(f"Error processing {validate_file} in {validation_folder_name}: {e}")
    else:
        print(f"Missing validation file: {validate_file} in {validation_folder_name}")

# Convert list to a 3D NumPy array
validation_data_3d = np.array(validation_data_3d)  # Shape should be (6, 28, 31)

# Step 4: Validate each dataset in the validation data
validation_results = {}

for i, X_validate_2d in enumerate(validation_data_3d):
    # Reshape to (1, 28*31) for SVM
    X_validate_svm = X_validate_2d.reshape(1, -1)
    X_validate_scaled = scaler.transform(X_validate_svm)

    # Validate One-Class SVM
    svm_scores = one_class_svm.decision_function(X_validate_scaled)

    # Validate Autoencoder
    reconstructions = autoencoder.predict(X_validate_scaled)
    autoencoder_mse = np.mean(np.power(X_validate_scaled - reconstructions, 2), axis=1)

    # Store results
    validation_results[f'Data {i+1} - SVM'] = svm_scores
    validation_results[f'Data {i+1} - Autoencoder'] = autoencoder_mse

# Step 5: Plot the validation results
results_df = pd.DataFrame(validation_results)
plt.figure(figsize=(12, 8))
sns.heatmap(results_df, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
plt.title(f'Anomaly Scores from SVM and Autoencoder on Validation Data (tb-13cc)')
plt.xlabel('Model')
plt.ylabel('Sample Index')
plt.show()
# Out:
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-7cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-8cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-9cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-10cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-11cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-12cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-15cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-16cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-17cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-18cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-19cc_openmsp430_0.csv
# ...

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import OneClassSVM
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt
import seaborn as sns

# Define the base directory
base_dir = 'glitchsweep_fsm_red'

# ID sets (representing different hash configurations)
id_sets = ['openmsp430_0', 'openmsp430_1', 'openmsp430_2', 'openmsp430_3', 'openmsp430_4', 'openmsp430_5']

# Folders for training and validation (these are part of file names, not actual directories)
train_folder_names = [
    'tb-7cc', 'tb-8cc', 'tb-9cc', 'tb-10cc', 'tb-11cc', 'tb-12cc',
    'tb-14cc', 'tb-15cc', 'tb-16cc', 'tb-17cc', 'tb-18cc', 'tb-19cc',
    'tb-21cc', 'tb-22cc', 'tb-23cc', 'tb-24cc', 'tb-25cc', 'tb-26cc',
    'tb-28cc', 'tb-29cc', 'tb-31cc', 'tb-32cc', 'tb-33cc'
]
validation_folder_name = 'tb-13cc'  # This is part of the file name, not an actual folder

# Function to read and preprocess CSV files into 2D arrays
def read_and_preprocess_csv(file_path):
    print(f"Loading data from: {file_path}")
    df = pd.read_csv(file_path, header=None, skiprows=1)  # Skip header
    if df.empty:
        raise ValueError(f"No data found in {file_path}.")
    
    # Convert hashed values to numeric using Label Encoding
    def convert_hashes_to_numeric(df):
        label_encoders = []
        for column in df.columns:
            le = LabelEncoder()
            df[column] = le.fit_transform(df[column].astype(str))
            label_encoders.append(le)
        return df, label_encoders

    df_numeric, label_encoders = convert_hashes_to_numeric(df)
    return df_numeric.values  # Return as a NumPy array

# Step 1: Create the 3D training dataset
train_data_3d = []

for set_name in id_sets:
    for train_folder_name in train_folder_names:
        train_file = f'extracted_hashes_{train_folder_name}_{set_name}.csv'
        train_file_path = os.path.join(base_dir, train_file)

        if os.path.exists(train_file_path):
            try:
                # Read and preprocess the CSV file into a 2D array (28, 31)
                data_2d = read_and_preprocess_csv(train_file_path)
                if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                    train_data_3d.append(data_2d)
                else:
                    print(f"Unexpected data shape {data_2d.shape} in {train_file_path}. Skipping this file.")
            except Exception as e:
                print(f"Error reading or processing {train_file} in {train_folder_name}: {e}")
        else:
            print(f"Missing training file: {train_file} in {train_folder_name}")

# Convert list to a 3D NumPy array
train_data_3d = np.array(train_data_3d)  # Shape will be (138, 28, 31)

# Step 2: Train models on the 3D training dataset

# Reshape train_data_3d to (138, 28*31) for SVM
X_train_svm = train_data_3d.reshape(138, -1)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_svm)

# Manual Grid Search for One-Class SVM
param_grid = {'nu': [0.01, 0.05, 0.1], 'gamma': ['scale', 'auto']}
best_svm_model = None
best_svm_score = -np.inf

for params in ParameterGrid(param_grid):
    svm = OneClassSVM(kernel='rbf', **params)
    svm.fit(X_train_scaled)
    
    # Custom scoring: Here we use the decision function as a proxy for anomaly detection quality
    scores = svm.decision_function(X_train_scaled)
    mean_score = np.mean(scores)
    
    if mean_score > best_svm_score:
        best_svm_score = mean_score
        best_svm_model = svm

# Train Autoencoder
input_layer = Input(shape=(X_train_scaled.shape[1],))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(X_train_scaled.shape[1], activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')
autoencoder.fit(X_train_scaled, X_train_scaled, epochs=100, batch_size=16, validation_split=0.1, verbose=0)

# Step 3: Create the 3D validation dataset and validate models
validation_data_3d = []

for set_name in id_sets:
    validate_file = f'fault_extracted_hashes_{validation_folder_name}_{set_name}.csv'
    validate_file_path = os.path.join(base_dir, validate_file)

    if os.path.exists(validate_file_path):
        try:
            # Read and preprocess the CSV file into a 2D array (28, 31)
            data_2d = read_and_preprocess_csv(validate_file_path)
            if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                validation_data_3d.append(data_2d)
            else:
                print(f"Unexpected data shape {data_2d.shape} in {validate_file_path}. Skipping this file.")
        except Exception as e:
            print(f"Error processing {validate_file} in {validation_folder_name}: {e}")
    else:
        print(f"Missing validation file: {validate_file} in {validation_folder_name}")

# Convert list to a 3D NumPy array
validation_data_3d = np.array(validation_data_3d)  # Shape should be (6, 28, 31)

# Step 4: Validate each dataset in the validation data
validation_results = {}

for i, X_validate_2d in enumerate(validation_data_3d):
    # Reshape to (1, 28*31) for SVM
    X_validate_svm = X_validate_2d.reshape(1, -1)
    X_validate_scaled = scaler.transform(X_validate_svm)

    # Validate One-Class SVM
    svm_scores = best_svm_model.decision_function(X_validate_scaled)

    # Validate Autoencoder
    reconstructions = autoencoder.predict(X_validate_scaled)
    autoencoder_mse = np.mean(np.power(X_validate_scaled - reconstructions, 2), axis=1)

    # Store results
    validation_results[f'Data {i+1} - SVM'] = svm_scores
    validation_results[f'Data {i+1} - Autoencoder'] = autoencoder_mse

# Step 5: Plot the validation results
results_df = pd.DataFrame(validation_results)
plt.figure(figsize=(12, 8))
sns.heatmap(results_df, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
plt.title(f'Anomaly Scores from SVM and Autoencoder on Validation Data (tb-13cc)')
plt.xlabel('Model')
plt.ylabel('Sample Index')
plt.show()
# Out:
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-7cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-8cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-9cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-10cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-11cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-12cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-15cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-16cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-17cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-18cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-19cc_openmsp430_0.csv
# ...

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

# Define the base directory
base_dir = 'glitchsweep_fsm_red'

# ID sets (representing different hash configurations)
id_sets = ['openmsp430_0', 'openmsp430_1', 'openmsp430_2', 'openmsp430_3', 'openmsp430_4', 'openmsp430_5']

# Folders for training and validation (these are part of file names, not actual directories)
train_folder_names = [
    'tb-7cc', 'tb-8cc', 'tb-9cc', 'tb-10cc', 'tb-11cc', 'tb-12cc',
    'tb-14cc', 'tb-15cc', 'tb-16cc', 'tb-17cc', 'tb-18cc', 'tb-19cc',
    'tb-21cc', 'tb-22cc', 'tb-23cc', 'tb-24cc', 'tb-25cc', 'tb-26cc',
    'tb-28cc', 'tb-29cc', 'tb-31cc', 'tb-32cc', 'tb-33cc'
]
validation_folder_name = 'tb-30cc'  # This is part of the file name, not an actual folder

# Function to read and preprocess CSV files into 2D arrays
def read_and_preprocess_csv(file_path):
    print(f"Loading data from: {file_path}")
    df = pd.read_csv(file_path, header=None, skiprows=1)  # Skip header
    if df.empty:
        raise ValueError(f"No data found in {file_path}.")
    
    # Convert hashed values to numeric using Label Encoding
    def convert_hashes_to_numeric(df):
        label_encoders = []
        for column in df.columns:
            le = LabelEncoder()
            df[column] = le.fit_transform(df[column].astype(str))
            label_encoders.append(le)
        return df, label_encoders

    df_numeric, label_encoders = convert_hashes_to_numeric(df)
    return df_numeric.values  # Return as a NumPy array

# Step 1: Create the 3D training dataset
train_data_3d = []

for set_name in id_sets:
    for train_folder_name in train_folder_names:
        train_file = f'extracted_hashes_{train_folder_name}_{set_name}.csv'
        train_file_path = os.path.join(base_dir, train_file)

        if os.path.exists(train_file_path):
            try:
                # Read and preprocess the CSV file into a 2D array (28, 31)
                data_2d = read_and_preprocess_csv(train_file_path)
                if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                    train_data_3d.append(data_2d)
                else:
                    print(f"Unexpected data shape {data_2d.shape} in {train_file_path}. Skipping this file.")
            except Exception as e:
                print(f"Error reading or processing {train_file} in {train_folder_name}: {e}")
        else:
            print(f"Missing training file: {train_file} in {train_folder_name}")

# Convert list to a 3D NumPy array
train_data_3d = np.array(train_data_3d)  # Shape will be (138, 28, 31)

# Step 2: Train Autoencoder on the 3D training dataset

# Reshape train_data_3d to (138, 28*31) for Autoencoder
X_train = train_data_3d.reshape(138, -1)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Define Autoencoder model with better tuning
input_layer = Input(shape=(X_train_scaled.shape[1],))
encoded = Dense(256, activation='relu')(input_layer)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(256, activation='relu')(decoded)
decoded = Dense(X_train_scaled.shape[1], activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the Autoencoder
autoencoder.fit(X_train_scaled, X_train_scaled, 
                epochs=200, 
                batch_size=16, 
                validation_split=0.1, 
                verbose=1,
                callbacks=[early_stopping])

# Step 3: Create the 3D validation dataset and validate the Autoencoder
validation_data_3d = []

for set_name in id_sets:
    validate_file = f'fault_extracted_hashes_{validation_folder_name}_{set_name}.csv'
    validate_file_path = os.path.join(base_dir, validate_file)

    if os.path.exists(validate_file_path):
        try:
            # Read and preprocess the CSV file into a 2D array (28, 31)
            data_2d = read_and_preprocess_csv(validate_file_path)
            if data_2d.shape == (28, 31):  # Ensure it has the correct shape
                validation_data_3d.append(data_2d)
            else:
                print(f"Unexpected data shape {data_2d.shape} in {validate_file_path}. Skipping this file.")
        except Exception as e:
            print(f"Error processing {validate_file} in {validation_folder_name}: {e}")
    else:
        print(f"Missing validation file: {validate_file} in {validation_folder_name}")

# Convert list to a 3D NumPy array
validation_data_3d = np.array(validation_data_3d)  # Shape should be (6, 28, 31)

# Step 4: Validate each dataset in the validation data
validation_results = {}

for i, X_validate_2d in enumerate(validation_data_3d):
    # Reshape to (1, 28*31) for Autoencoder
    X_validate = X_validate_2d.reshape(1, -1)
    X_validate_scaled = scaler.transform(X_validate)

    # Validate Autoencoder
    reconstructions = autoencoder.predict(X_validate_scaled)
    autoencoder_mse = np.mean(np.power(X_validate_scaled - reconstructions, 2), axis=1)

    # Store results
    validation_results[f'Core {i} - Autoencoder'] = autoencoder_mse

# Step 5: Plot the validation results
results_df = pd.DataFrame(validation_results)
plt.figure(figsize=(12, 8))
sns.heatmap(results_df, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
plt.title(f'Anomaly Scores from Autoencoder on Validation Data (tb-13cc)')
plt.xlabel('Sample Index')
plt.ylabel('Validation Data')
plt.show()
# Out:
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-7cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-8cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-9cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-10cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-11cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-12cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-14cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-15cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-16cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-17cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-18cc_openmsp430_0.csv
# Loading data from: glitchsweep_fsm_red/extracted_hashes_tb-19cc_openmsp430_0.csv
# ...
